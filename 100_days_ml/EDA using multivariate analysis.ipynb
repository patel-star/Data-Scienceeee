# %%
# !mkdir "%USERPROFILE%\.kaggle" 2> nul
# !copy kaggle.json "%USERPROFILE%\.kaggle\" > nul

# %%
# !kaggle datasets download -d sakshisatre/tips-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sakshisatre/tips-dataset
# License(s): apache-2.0
# tips-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
import os

zip_path = r'C:\Users\Patel_asus\ml 100 days\tips-dataset.zip'

# Extract to current directory
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall()
    
print(f"Files extracted to: {os.getcwd()}")
# Out:
# Files extracted to: C:\Users\Patel_asus\ml 100 days

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

tt = pd.read_csv('Titanic.csv')
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
flight = sns.load_dataset('flights') #this dataset is already in seaborn
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
iris = sns.load_dataset('iris') #iris is also in seaborn
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
tips = pd.read_csv('tip.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # 1. numerical - numerical : scatterplot

# %%
# sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
sns.scatterplot(x=tips.total_bill,y=tips.tip) #same:
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips.sex)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips.sex,style=tips.smoker)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips.sex,style=tips.smoker,size=tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2. numerical - categorical :- Bar Plot

# %%
tt.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x=tt.Pclass,y=tt.Fare)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x=tt.Pclass,y=tt.Fare,hue=tt.Sex)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# <!-- 3. Numerical - Categorical :- Box Plot -->

# %% [markdown]
# # 3. numerical - categorical :- box plot

# %%
sns.boxplot(x=tt.Sex,y=tt.Age)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=tt.Sex,y=tt.Age,hue=tt.Survived)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # 4. numerical - categorical :- histplot

# %%
# sns.distplot(tt.Age)
sns.histplot(tt.Age, kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.kdeplot(tt[tt['Survived']==0]['Age'])
sns.kdeplot(tt[tt['Survived']==1]['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # categorical - categorical :- heatmap

# %%
pd.crosstab(tt.Pclass,tt.Survived)
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(tt.Pclass,tt.Survived))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
#must have three argument: values, index, columns: just like this:
flight.pivot_table('passengers','month','year') 
# or
flight.pivot_table(values = 'passengers',index = 'month',columns='year')
# Out:
# C:\Users\Patel_asus\AppData\Local\Temp\ipykernel_1368\999482807.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flight.pivot_table('passengers','month','year')
# C:\Users\Patel_asus\AppData\Local\Temp\ipykernel_1368\999482807.py:4: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flight.pivot_table(values = 'passengers',index = 'month',columns='year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# ...

# %%
sns.heatmap(flight.pivot_table('passengers','month','year') )
# heat map is best when there are lot of numerical numerical comparison:
# Out:
# C:\Users\Patel_asus\AppData\Local\Temp\ipykernel_1368\3748558552.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flight.pivot_table('passengers','month','year') )
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flight.pivot_table('passengers','month','year') )
# this merges the ones with same behaviour
# Out:
# C:\Users\Patel_asus\AppData\Local\Temp\ipykernel_1368\118580453.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flight.pivot_table('passengers','month','year') )

# %%
tt.groupby('Pclass')['Survived'].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
# its showing 62.9% in Pclass survived:
(tt.groupby('Pclass')['Survived'].mean()*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# # 6. categorical - categorical :- clustermap

# %%
pd.crosstab(tt.SibSp,tt.Survived)
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.clustermap(pd.crosstab(tt.SibSp,tt.Survived))

# %%
# its not clear in bottom rows, lets change siblingspouse to parentchild:
sns.clustermap(pd.crosstab(tt.Parch,tt.Survived))
# this is also called dendogram-shows heirarichal relation

# %% [markdown]
# # 7. Pairplot

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# # 8. numerical - numerical: Lineplot

# %%
new = flight.groupby('year').sum('passengers')
new
# Out:
#       passengers
# year
# 1949        1520
# 1950        1676
# 1951        2042
# 1952        2364
# 1953        2700
# 1954        2867
# 1955        3408
# 1956        3939
# 1957        4421
# 1958        4572
# 1959        5140
# 1960        5714

# %%
sns.lineplot(new)
# Out:
# <Axes: xlabel='year'>
